# %% [markdown]
# # Program 1:- N-gram

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.10.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting defusedxml (from nltk)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting click (from nltk)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2026.7.19-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in .\myenv\Lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.10.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 1.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.4 MB/s  0:00:01
# Using cached regex-2026.7.19-cp314-cp314-win_amd64.whl (280 kB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached tqdm-4.70.0-py3-none-any.whl (80 kB)
# Installing collected packages: tqdm, regex, joblib, defusedxml, click, nltk
#
#    ------ --------------------------------- 1/6 [regex]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    -------------------------- ------------- 4/6 [click]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    --------------------------------- ------ 5/6 [nltk]
#    ---------------------------------------- 6/6 [nltk]
#
# Successfully installed click-8.4.2 defusedxml-0.7.1 joblib-1.5.3 nltk-3.10.3 regex-2026.7.19 tqdm-4.70.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from nltk import ngrams

# %%
sentence='There was heavy rain'
n=int(input('Enter the value of n: '))
n_grams=ngrams(sentence.split(),n)

print("\n")
for grams in n_grams:
    print(grams)
# Out:
# ('There', 'was')
# ('was', 'heavy')
# ('heavy', 'rain')

# %% [markdown]
# # Program 2:- N-gram Using TextBlob

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.20.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in .\myenv\Lib\site-packages (from textblob) (3.10.3)
# Requirement already satisfied: defusedxml in .\myenv\Lib\site-packages (from nltk>=3.9->textblob) (0.7.1)
# Requirement already satisfied: click in .\myenv\Lib\site-packages (from nltk>=3.9->textblob) (8.4.2)
# Requirement already satisfied: joblib in .\myenv\Lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\myenv\Lib\site-packages (from nltk>=3.9->textblob) (2026.7.19)
# Requirement already satisfied: tqdm in .\myenv\Lib\site-packages (from nltk>=3.9->textblob) (4.70.0)
# Requirement already satisfied: colorama in .\myenv\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.1-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 2.1 MB/s  0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.20.1
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

#sample sentence for N-gram detection
sentence=input('Enter the sentence:')
n=int(input('Enter the value of n:'))
ngram_object=TextBlob(sentence)

# %%
# computing N-grams
ngrams=ngram_object.ngrams(n)
print('\n')

for grams in ngrams:
    print(grams)
# Out:
# ['There', 'was']
# ['was', 'heavy']
# ['heavy', 'rain']
